# %%
# %load_ext autoreload
# %autoreload 2

import itertools
import json
import os 
import pandas as pd
import pathlib
import requests

from utils import *

# %% [markdown]
# ### GBIF

# %%
local_file = "gbif"
# !ls gbif/
# Out:
# Piper+0.json	 Piper+1311.json  Piper+383.json  Piper+695.json
# Piper+1000.json  Piper+1312.json  Piper+384.json  Piper+696.json
# Piper+1001.json  Piper+1313.json  Piper+385.json  Piper+697.json
# Piper+1002.json  Piper+1314.json  Piper+386.json  Piper+698.json
# Piper+1003.json  Piper+1315.json  Piper+387.json  Piper+699.json
# Piper+1004.json  Piper+1316.json  Piper+388.json  Piper+69.json
# Piper+1005.json  Piper+1317.json  Piper+389.json  Piper+6.json
# Piper+1006.json  Piper+1318.json  Piper+38.json   Piper+700.json
# Piper+1007.json  Piper+1319.json  Piper+390.json  Piper+701.json
# Piper+1008.json  Piper+131.json   Piper+391.json  Piper+702.json
# Piper+1009.json  Piper+1320.json  Piper+392.json  Piper+703.json
# Piper+100.json	 Piper+1321.json  Piper+393.json  Piper+704.json
# Piper+1010.json  Piper+1322.json  Piper+394.json  Piper+705.json
# Piper+1011.json  Piper+1323.json  Piper+395.json  Piper+706.json
# Piper+1012.json  Piper+1324.json  Piper+396.json  Piper+707.json
# ...

# %%
files = [p for p in pathlib.Path(local_file).rglob("*.json")]
results = []
for f in files:
    print(f)
    with open(f, "r") as arquivo:
        data = json.load(arquivo)
        if data and "results" in data and len(data["results"]) > 0:
            results.append(data["results"])
print("qtd em results: %d" % len(results))
# Out:
# gbif/Piper+812.json
# gbif/Piper+888.json
# gbif/Piper+600.json
# gbif/Piper+496.json
# gbif/Piper+1098.json
# gbif/Piper+137.json
# gbif/Piper+99.json
# gbif/Piper+1052.json
# gbif/Piper+896.json
# gbif/Piper+394.json
# gbif/Piper+1334.json
# gbif/Piper+746.json
# gbif/Piper+747.json
# gbif/Piper+168.json
# gbif/Piper+1347.json
# gbif/Piper+714.json
# gbif/Piper+217.json
# gbif/Piper+695.json
# gbif/Piper+1213.json
# gbif/Piper+204.json
# gbif/Piper+624.json
# gbif/Piper+846.json
# gbif/Piper+1158.json
# gbif/Piper+557.json
# gbif/Piper+810.json
# gbif/Piper+1142.json
# gbif/Piper+471.json
# gbif/Piper+1109.json
# gbif/Piper+271.json
# gbif/Piper+605.json
# gbif/Piper+1222.json
# gbif/Piper+336.json
# gbif/Piper+1.json
# gbif/Piper+1095.json
# gbif/Piper+1138.json
# gbif/Piper+549.json
# gbif/Piper+1012.json
# gbif/Piper+678.json
# gbif/Piper+144.json
# gbif/Piper+773.json
# gbif/Piper+389.json
# gbif/Piper+979.json
# gbif/Piper+82.json
# gbif/Piper+51.json
# gbif/Piper+106.json
# ...

# %%
data = list(itertools.chain(*(r for r in results)))
d2= dict(itertools.chain.from_iterable(d.items() for d in data))
df = pd.json_normalize(data)
df
# Out:
#               key                            datasetKey  \
# 0      2998027570  a185d0c4-1a12-45c1-a729-2a7b058b528d
# 1      3390903613  26d97e94-6ee9-4d5a-a9b8-7d514ec0345c
# 2      4031562717  7bd65a7a-f762-11e1-a439-00145eb45e9a
# 3      4031950051  7bd65a7a-f762-11e1-a439-00145eb45e9a
# 4      4061265601  e053ff53-c156-4e2e-b9b5-4462e9625424
# ...           ...                                   ...
# 27551  4139009143  fcb4e601-a1d8-44b6-a9d6-75fd05a280ef
# 27552  4455786333  06f0d5c6-aeab-4205-ac9d-9b2d801a43a8
# 27553  1258611529  7bd65a7a-f762-11e1-a439-00145eb45e9a
# 27554  1260437885  7bd65a7a-f762-11e1-a439-00145eb45e9a
# 27555  1260441836  7bd65a7a-f762-11e1-a439-00145eb45e9a
#
#                            publishingOrgKey  \
# 0      838537fc-4aeb-4980-8b58-97fbdcd1d91a
# 1      073e52d4-44bd-41d7-bdfa-88c2735c694b
# 2      90fd6680-349f-11d8-aa2d-b8a03c50a862
# 3      90fd6680-349f-11d8-aa2d-b8a03c50a862
# 4      90fd6680-349f-11d8-aa2d-b8a03c50a862
# ...

# %%
print(df.shape)
filename = os.path.join(local_file, "gbif.parquet")
df.to_parquet(filename)
# !ls gbif/
# Out:
# (27556, 244)
# gbif.parquet  Piper.js+json.zip

# %% [markdown]
# ### IUCN

# %%
local_file = "iucn"
# !unzip iucn/redlist_species_data_7754f86d-b43c-4153-883d-28f8aa46db53.zip
# !ls iucn/redlist_species_data_7754f86d-b43c-4153-883d-28f8aa46db53
# Out:
# Archive:  iucn/redlist_species_data_7754f86d-b43c-4153-883d-28f8aa46db53.zip
#   inflating: taxonomy_with_html.csv
#   inflating: taxonomy.csv
#   inflating: assessments.csv
#   inflating: IUCN Red List_Terms and Conditions of Use_v3.pdf
#   inflating: ReadMe.txt
#   inflating: assessments_with_html.csv
# ls: não foi possível acessar 'iucn/redlist_species_data_7754f86d-b43c-4153-883d-28f8aa46db53': Arquivo ou diretório inexistente

# %%
df_taxonomy = pd.read_csv("iucn/redlist_species_data_7754f86d-b43c-4153-883d-28f8aa46db53/taxonomy.csv")
df_taxonomy.head()
# Out:
#    internalTaxonId        scientificName kingdomName    phylumName  \
# 0            45862        Piper skutchii     PLANTAE  TRACHEOPHYTA
# 1            45861        Piper schuppii     PLANTAE  TRACHEOPHYTA
# 2            45863         Piper sodiroi     PLANTAE  TRACHEOPHYTA
# 3            45864      Piper stipulosum     PLANTAE  TRACHEOPHYTA
# 4            45814  Piper achupallasense     PLANTAE  TRACHEOPHYTA
#
#        className  orderName  familyName genusName     speciesName  infraType  \
# 0  MAGNOLIOPSIDA  PIPERALES  PIPERACEAE     Piper        skutchii        NaN
# 1  MAGNOLIOPSIDA  PIPERALES  PIPERACEAE     Piper        schuppii        NaN
# 2  MAGNOLIOPSIDA  PIPERALES  PIPERACEAE     Piper         sodiroi        NaN
# 3  MAGNOLIOPSIDA  PIPERALES  PIPERACEAE     Piper      stipulosum        NaN
# 4  MAGNOLIOPSIDA  PIPERALES  PIPERACEAE     Piper  achupallasense        NaN
#
#    infraName  infraAuthority  subpopulationName           authority  \
# ...

# %%
df_assessments = pd.read_csv("iucn/redlist_species_data_7754f86d-b43c-4153-883d-28f8aa46db53/assessments.csv")
df_assessments.head()
# Out:
#    assessmentId  internalTaxonId        scientificName        redlistCategory  \
# 0      11015485            45862        Piper skutchii             Endangered
# 1      11015569            45861        Piper schuppii             Vulnerable
# 2      11015653            45863         Piper sodiroi             Vulnerable
# 3      11015737            45864      Piper stipulosum  Critically Endangered
# 4      11016854            45814  Piper achupallasense             Endangered
#
#   redlistCriteria  yearPublished           assessmentDate  criteriaVersion  \
# 0       B1ab(iii)           2004  2004-04-30 00:00:00 UTC              3.1
# 1              D2           2004  2004-04-30 00:00:00 UTC              3.1
# 2       B1ab(iii)           2004  2004-04-30 00:00:00 UTC              3.1
# 3       B1ab(iii)           2004  2004-04-30 00:00:00 UTC              3.1
# 4       B1ab(iii)           2004  2004-04-30 00:00:00 UTC              3.1
#
# ...

# %%
df = pd.merge(df_taxonomy, df_assessments, on="internalTaxonId")
df.head()
# Out:
#    internalTaxonId      scientificName_x kingdomName    phylumName  \
# 0            45862        Piper skutchii     PLANTAE  TRACHEOPHYTA
# 1            45861        Piper schuppii     PLANTAE  TRACHEOPHYTA
# 2            45863         Piper sodiroi     PLANTAE  TRACHEOPHYTA
# 3            45864      Piper stipulosum     PLANTAE  TRACHEOPHYTA
# 4            45814  Piper achupallasense     PLANTAE  TRACHEOPHYTA
#
#        className  orderName  familyName genusName     speciesName  infraType  \
# 0  MAGNOLIOPSIDA  PIPERALES  PIPERACEAE     Piper        skutchii        NaN
# 1  MAGNOLIOPSIDA  PIPERALES  PIPERACEAE     Piper        schuppii        NaN
# 2  MAGNOLIOPSIDA  PIPERALES  PIPERACEAE     Piper         sodiroi        NaN
# 3  MAGNOLIOPSIDA  PIPERALES  PIPERACEAE     Piper      stipulosum        NaN
# 4  MAGNOLIOPSIDA  PIPERALES  PIPERACEAE     Piper  achupallasense        NaN
#
#    ...  populationTrend                                              range  \
# ...

# %%
filename = os.path.join(local_file, "red_list_iucn.parquet")
df.to_parquet(filename)
# !ls iucn/
# Out:
# red_list_iucn.parquet
# redlist_species_data_7754f86d-b43c-4153-883d-28f8aa46db53
# redlist_species_data_7754f86d-b43c-4153-883d-28f8aa46db53.zip
