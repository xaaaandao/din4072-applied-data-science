# %%
# %load_ext autoreload
# %autoreload 2
import duckdb
import os
import pandas as pd

import splink

from ibge import *
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
start = 1
limits = 0
url = "https://specieslink.net/ws/1.0/search?apikey=%s&offset=%d&limits=%d&kingdom=Plantae" % (os.environ["SPLINK"], start, limits)
print("start: %d limits: %d" % (start, limits))
print("url: %s")
# Out:
# start: 1 limits: 0
# url: %s

# %%
splink.download_specieslink()
print("total files: %d" % len(os.listdir("./parquet")))
# Out:
# start: 0 limits: 99
# start: 100 limits: 199
# start: 200 limits: 299
# start: 300 limits: 399
# start: 400 limits: 499
# start: 500 limits: 599
# start: 600 limits: 699
# start: 700 limits: 799

# %%
# Initialize DuckDB connection
conn = duckdb.connect()

local_file = "./parquet"

conn.execute("DROP TABLE IF EXISTS specieslink")
conn.execute(f"""
    CREATE TABLE specieslink AS
    SELECT * FROM read_parquet('{local_file}', union_by_name=True)
""")

result = conn.execute("SELECT COUNT(*) FROM specieslink").fetchone()
print(f"Registros carregados na tabela: {result[0]:,}")
# Out:
# Registros carregados na tabela: 22,000

# %%
conn.execute("DESCRIBE specieslink").df()
# Out:
#                  column_name column_type null   key default extra
# 0                    barcode     VARCHAR  YES  None    None  None
# 1             collectioncode     VARCHAR  YES  None    None  None
# 2             scientificname     VARCHAR  YES  None    None  None
# 3                    kingdom     VARCHAR  YES  None    None  None
# 4                     family     VARCHAR  YES  None    None  None
# 5                      genus     VARCHAR  YES  None    None  None
# 6              yearcollected     VARCHAR  YES  None    None  None
# 7             monthcollected     VARCHAR  YES  None    None  None
# 8               daycollected     VARCHAR  YES  None    None  None
# 9                    country     VARCHAR  YES  None    None  None
# 10             stateprovince     VARCHAR  YES  None    None  None
# 11            continentocean     VARCHAR  YES  None    None  None
# 12                  locality     VARCHAR  YES  None    None  None
# 13           institutioncode     VARCHAR  YES  None    None  None
# 14             basisofrecord     VARCHAR  YES  None    None  None
# 15              identifiedby     VARCHAR  YES  None    None  None
# 16            yearidentified     VARCHAR  YES  None    None  None
# 17          verbatimlatitude     VARCHAR  YES  None    None  None
# 18         verbatimlongitude     VARCHAR  YES  None    None  None
# 19              collectionid      BIGINT  YES  None    None  None
# 20           specificepithet     VARCHAR  YES  None    None  None
# 21                recordedby     VARCHAR  YES  None    None  None
# 22          decimallongitude     VARCHAR  YES  None    None  None
# 23           decimallatitude     VARCHAR  YES  None    None  None
# 24                  modified     VARCHAR  YES  None    None  None
# 25  scientificnameauthorship     VARCHAR  YES  None    None  None
# 26              recordnumber     VARCHAR  YES  None    None  None
# 27         occurrenceremarks     VARCHAR  YES  None    None  None
# 28             catalognumber     VARCHAR  YES  None    None  None
# 29                    county     VARCHAR  YES  None    None  None
# 30  minimumelevationinmeters     VARCHAR  YES  None    None  None
# 31  maximumelevationinmeters     VARCHAR  YES  None    None  None
# 32           monthidentified     VARCHAR  YES  None    None  None
# 33             dayidentified     VARCHAR  YES  None    None  None
# 34      infraspecificepithet     VARCHAR  YES  None    None  None
# 35                typestatus     VARCHAR  YES  None    None  None
# 36          relationshiptype     VARCHAR  YES  None    None  None
# 37        relatedcatalogitem     VARCHAR  YES  None    None  None
# 38       coordinateprecision     VARCHAR  YES  None    None  None
# 39                    phylum     VARCHAR  YES  None    None  None
# 40                     class     VARCHAR  YES  None    None  None
# 41                     order     VARCHAR  YES  None    None  None
# 42               fieldnumber     VARCHAR  YES  None    None  None

# %%
conn.execute("SELECT * FROM specieslink LIMIT 5").df()
# Out:
#       barcode     collectioncode      scientificname  kingdom          family  \
# 0  CONV005839  CONVOLVULACEAE_BR  Bonamia ferruginea  Plantae  Convolvulaceae
# 1        None               CPAP                None  Plantae         Poaceae
# 2  CONV005840  CONVOLVULACEAE_BR  Bonamia ferruginea  Plantae  Convolvulaceae
# 3        None               CPAP                None  Plantae         Poaceae
# 4  CONV005829  CONVOLVULACEAE_BR  Bonamia ferruginea  Plantae  Convolvulaceae
#
#      genus yearcollected monthcollected daycollected country  ...  \
# 0  Bonamia          1974             07           29  Brazil  ...
# 1     None          1989             09           23  Brasil  ...
# 2  Bonamia          1974             07           29  Brazil  ...
# 3     None          1991             04           11  Brasil  ...
# 4  Bonamia          1975             08           04  Brazil  ...
#
#   dayidentified infraspecificepithet typestatus relationshiptype  \
# 0          None                 None       None             None
# 1          None                 None       None             None
# 2          None                 None       None             None
# 3          None                 None       None             None
# 4          None                 None       None             None
#
#   relatedcatalogitem coordinateprecision phylum class order  fieldnumber
# 0               None                None   None  None  None         None
# 1               None                None   None  None  None         None
# 2               None                None   None  None  None         None
# 3               None                None   None  None  None         None
# 4               None                None   None  None  None         None
#
# [5 rows x 43 columns]

# %%
response = get_data_ibge()
data = [{"id": r["id"], "nome_cidade": r["nome"], "sigla": get_sigla(r), "nome_estado": get_nome_uf(r)} for r in response.json()]

df = pd.DataFrame.from_records(data)
conn.execute("DROP TABLE IF EXISTS ibge")
conn.execute(f"""
    CREATE TABLE ibge AS
    SELECT * FROM df
""")

result = conn.execute("SELECT COUNT(*) FROM ibge").fetchone()
print(f"Registros carregados na tabela: {result[0]:,}")
# Out:
# Registros carregados na tabela: 5,571

# %%
conn.execute("SELECT * FROM ibge LIMIT 5").df()
# Out:
#         id            nome_cidade sigla nome_estado
# 0  1100015  Alta Floresta D'Oeste    RO    Rondônia
# 1  1100023              Ariquemes    RO    Rondônia
# 2  1100031                 Cabixi    RO    Rondônia
# 3  1100049                 Cacoal    RO    Rondônia
# 4  1100056             Cerejeiras    RO    Rondônia

# %%
conn.execute("SELECT specieslink.stateprovince FROM specieslink LIMIT 5").df()
# Out:
#   stateprovince
# 0      Amazonas
# 1            MS
# 2      Amazonas
# 3            MS
# 4      Amazonas

# %%
conn.execute("DROP TABLE IF EXISTS specieslink_sigla")
conn.execute("""
            CREATE TABLE specieslink_sigla AS
            SELECT
                COALESCE(ibge.sigla, specieslink.stateprovince) AS state_province
            FROM specieslink
                     LEFT JOIN ibge
                               ON specieslink.stateprovince = ibge.sigla
            """)

conn.execute("COPY specieslink_sigla TO 'specieslink_sigla.parquet' (FORMAT PARQUET)")

# %%
conn.execute("SELECT distinct(specieslink_sigla.state_province) FROM specieslink_sigla LIMIT 5").df()
# Out:
#   state_province
# 0           Pará
# 1         Paraná
# 2        Pastaza
# 3           Puno
# 4        Monagas

# %%
conn.execute("DROP TABLE IF EXISTS specieslink_nome_estado")
conn.execute("""
             CREATE TABLE specieslink_nome_estado AS
             SELECT
                 COALESCE(ibge.nome_estado, specieslink_sigla.state_province) AS state_province
             FROM specieslink_sigla
                      LEFT JOIN ibge
                                ON specieslink_sigla.state_province = ibge.nome_estado
             """)

conn.execute("COPY specieslink_nome_estado TO 'specieslink_nome_estado.parquet' (FORMAT PARQUET)")

# %%
conn.execute("SELECT distinct(specieslink_nome_estado.state_province) FROM specieslink_nome_estado LIMIT 5").df()
# Out:
#   state_province
# 0        Huánuco
# 1           Napo
# 2      Pichincha
# 3       Apurímac
# 4         Biobío

# %%
conn.execute("SELECT \
stateprovince, \
COUNT(DISTINCT family) AS num_families \
FROM specieslink \
WHERE family IS NOT NULL AND stateprovince IS NOT NULL \
GROUP BY stateprovince \
ORDER BY num_families DESC;").df()
# Out:
#         stateprovince  num_families
# 0           São Paulo            80
# 1                  MS            64
# 2         Mato Grosso            62
# 3               Goiás            39
# 4            Amazonas            38
# ..                ...           ...
# 229            Rovinj             1
# 230        Edo Falcón             1
# 231  Zamora Chinchipe             1
# 232            Itapúa             1
# 233   Mahaica-Berbice             1
#
# [234 rows x 2 columns]
